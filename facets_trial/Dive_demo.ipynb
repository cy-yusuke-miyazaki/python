# %%
# Load UCI census and convert to json for sending to the visualization
import pandas as pd
features = ["Age", "Workclass", "fnlwgt", "Education", "Education-Num", "Marital Status",
            "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss",
            "Hours per week", "Country", "Target"]
jsonstr = pd.read_csv(
    "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test",
    names=features,
    sep=r'\s*,\s*',
    engine='python',
    skiprows=[0],
    na_values="?").to_json(orient='records')

# %%
import pandas as pd
import re

# %%
features = ["駅名（＊放置禁止区域に指定）", "放置台数（Ａ）自転車", "放置台数（Ａ）原付", "放置台数（Ａ）自二", "放置台数（Ａ）計","実収容台数（Ｂ）自転車","実収容台数（Ｂ）原付","実収容台数（Ｂ）計","収容能力（Ｃ）自転車","収容能力（Ｃ）原付","収容能力（Ｃ）計","乗入台数（Ａ）＋（Ｂ）計"]
dataset = pd.read_csv(
"http://www.seisyounen-chian.metro.tokyo.jp/kotsu/pdf/koutuu/csv/heisei27nendoekibetuhoutinirinsyanozyoukyou_1.csv",
    names=features,
    sep=r'\s*,\s*',
    engine='python',
    skiprows=[0],
    na_values='na',
    encoding="utf-8_sig"
)
dataset = dataset[dataset["駅名（＊放置禁止区域に指定）"] != "計"]
dataset = dataset[dataset["駅名（＊放置禁止区域に指定）"] != "区部計"]
dataset = dataset[dataset["駅名（＊放置禁止区域に指定）"] != "総数"]
dataset = dataset.replace(re.compile('＊'), '') #なんか＊が入ってて気持ち悪いので削除
jsonstr = dataset.to_json(orient='records')

# %%
# Display the Dive visualization for this data
from IPython.core.display import display, HTML

HTML_TEMPLATE = """<link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
        <facets-dive id="elem" height="600"></facets-dive>
        <script>
          var data = {jsonstr};
          document.querySelector("#elem").data = data;
        </script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
# <link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
#         <facets-dive id="elem" height="600"></facets-dive>
#         <script>
#           var data = [{"\u99c5\u540d\uff08\uff0a\u653e\u7f6e\u7981\u6b62\u533a\u57df\u306b\u6307\u5b9a\uff09":"\u6709\u697d\u753a\u99c5","\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u81ea\u8ee2\u8eca":261.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u539f\u4ed8":3.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u81ea\u4e8c":null,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u8a08":264.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u81ea\u8ee2\u8eca":118.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u539f\u4ed8":null,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u8a08":118.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u81ea\u8ee2\u8eca":174.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u539f\u4ed8":null,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u8a08":174.0,"\u4e57\u5165\u53f0\u6570\uff08\uff21\uff09\uff0b\uff08\uff22\uff09\u8a08":382.0},{"\u99c5\u540d\uff08\uff0a\u653e\u7f6e\u7981\u6b62\u533a\u57df\u306b\u6307\u5b9a\uff09":"\u6771\u4eac\u99c5","\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u81ea\u8ee2\u8eca":233.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u539f\u4ed8":1.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u81ea\u4e8c":6.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u8a08":240.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u81ea\u8ee2\u8eca":121.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u539f\u4ed8":5.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u8a08":126.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u81ea\u8ee2\u8eca":244.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u539f\u4ed8":5.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u8a08":249.0,"\u4e57\u5165\u53f0\u6570\uff08\uff21\uff09\uff0b\uff08\uff22\uff09\u8a08":366.0},{"\u99c5\u540d\uff08\uff0a\u653e\u7f6e\u7981\u6b62\u533a\u57df\u306b\u6307\u5b9a\uff09":"\u795e\u7530\u99c5","\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u81ea\u8ee2\u8eca":321.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u539f\u4ed8":18.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u81ea\u4e8c":13.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u8a08":352.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u81ea\u8ee2\u8eca":176.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u539f\u4ed8":13.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u8a08":189.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u81ea\u8ee2\u8eca":195.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u539f\u4ed8":20.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u8a08":215.0,"\u4e57\u5165\u53f0\u6570\uff08\uff21\uff09\uff0b\uff08\uff22\uff09\u8a08":541.0},{"\u99c5\u540d\uff08\uff0a\u653e\u7f6e\u7981\u6b62\u533a\u57df\u306b\u6307\u5b9a\uff09":"\u79cb\u8449\u539f\u99c5","\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u81ea\u8ee2\u8eca":584.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u539f\u4ed8":8.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u81ea\u4e8c":5.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u8a08":597.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u81ea\u8ee2\u8eca":593.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u539f\u4ed8":32.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u8a08":625.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u81ea\u8ee2\u8eca":765.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u539f\u4ed8":32.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u8a08":797.0,"\u4e57\u5165\u53f0\u6570\uff08\uff21\uff09\uff0b\uff08\uff22\uff09\u8a08":1222.0},{"\u99c5\u540d\uff08\uff0a\u653e\u7f6e\u7981\u6b62\u533a\u57df\u306b\u6307\u5b9a\uff09":"\u5fa1\u8336\u30ce\u6c34\u99c5","\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u81ea\u8ee2\u8eca":197.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u539f\u4ed8":6.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u81ea\u4e8c":4.0,"\u653e\u7f6e\u53f0\u6570\uff08\uff21\uff09\u8a08":207.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u81ea\u8ee2\u8eca":80.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u539f\u4ed8":10.0,"\u5b9f\u53ce\u5bb9\u53f0\u6570\uff08\uff22\uff09\u8a08":90.0,"\u53ce\u5bb9\u80fd\u529b\uff08\uff23\uff09\u81ea\u8ee2\u8e ...
