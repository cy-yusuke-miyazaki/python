# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
from pandas_datareader import data

# %%
from datetime import datetime

# %%
import pandas_datareader.data as web

# %%
#アメリカのハイテク企業の株価
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

# %%
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

# %%
#リストにある4社の株価をヤフーから取得
for stock in tech_list:
    globals()[stock] = web.DataReader(stock, 'yahoo', start, end)

# %%
type(AAPL)
# Out:
# pandas.core.frame.DataFrame

# %%
AAPL.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   146.101793  147.057291  145.177291  146.227888  145.049700
# std     16.199991   16.235193   15.862643   16.041501   16.532973
# min    109.260002  110.029999  108.250000  109.110001  107.383171
# 25%    139.004998  139.785004  138.629997  139.169998  137.561257
# 50%    147.169998  148.279999  145.809998  147.509995  145.804855
# 75%    156.900002  157.790001  155.739998  156.480004  155.907204
# max    175.110001  176.240005  174.649994  176.240005  175.608719
#
#              Volume
# count  2.510000e+02
# mean   2.734528e+07
# std    1.143549e+07
# min    1.402670e+07
# 25%    2.045495e+07
# 50%    2.450720e+07
# 75%    3.083610e+07
# max    1.119850e+08

# %%
AAPL.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-12-05  110.000000  110.029999  108.250000  109.110001  107.383171
# 2016-12-06  109.500000  110.360001  109.190002  109.949997  108.209877
# 2016-12-07  109.260002  111.190002  109.160004  111.029999  109.272781
# 2016-12-08  110.860001  112.430000  110.599998  112.120003  110.345543
# 2016-12-09  112.309998  114.699997  112.309998  113.949997  112.146576
#
#               Volume
# Date
# 2016-12-05  34324500
# 2016-12-06  26195500
# 2016-12-07  29998700
# 2016-12-08  27068300
# 2016-12-09  34402600

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2016-12-05 to 2017-12-01
# Data columns (total 6 columns):
# Open         251 non-null float64
# High         251 non-null float64
# Low          251 non-null float64
# Close        251 non-null float64
# Adj Close    251 non-null float64
# Volume       251 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 13.7 KB

# %%
AAPL['Close'].plot(legend=True, figsize=(15,4))

# %%
AAPL['Volume'].plot(legend=True, figsize=(15,4))

# %%
AAPL['Close'].rolling(10).mean()
# Out:
# Date
# 2016-12-05           NaN
# 2016-12-06           NaN
# 2016-12-07           NaN
# 2016-12-08           NaN
# 2016-12-09           NaN
# 2016-12-12           NaN
# 2016-12-13           NaN
# 2016-12-14           NaN
# 2016-12-15           NaN
# 2016-12-16    113.163000
# 2016-12-19    113.916000
# 2016-12-20    114.616000
# 2016-12-21    115.219000
# 2016-12-22    115.636000
# 2016-12-23    115.893000
# 2016-12-27    116.289000
# 2016-12-28    116.446000
# 2016-12-29    116.600000
# 2016-12-30    116.600000
# 2017-01-03    116.618000
# 2017-01-04    116.556000
# 2017-01-05    116.522000
# 2017-01-06    116.607001
# 2017-01-09    116.877001
# 2017-01-10    117.136001
# 2017-01-11    117.385001
# 2017-01-12    117.634001
# 2017-01-13    117.865000
# 2017-01-17    118.283000
# 2017-01-18    118.667000
#                  ...
# 2017-10-20    157.362000
# 2017-10-23    157.395000
# 2017-10-24    157.515001
# 2017-10-25    157.501001
# 2017-10-26    157.642001
# 2017-10-27    158.248001
# 2017-10-30    158.932001
# 2017-10-31    159.789000
# 2017-11-01    160.502000
# 2017-11-02    161.715001
# 2017-11-03    163.340001
# 2017-11-06    165.148001
# 2017-11-07    166.919000
# 2017-11-08    168.902000
# 2017-11-09    170.749001
# 2017-11-10    171.911000
# 2017-11-13    172.636000
# 2017-11-14    172.866000
# 2017-11-15    173.085001
# 2017-11-16    173.384001
# 2017-11-17    173.149001
# 2017-11-20    172.722000
# 2017-11-21    172.555000
# 2017-11-22    172.427000
# 2017-11-24    172.336000
# 2017-11-27    172.278000
# 2017-11-28    172.188000
# 2017-11-29    172.002000
# 2017-11-30    172.279001
# 2017-12-01    172.274001
# Name: Close, Length: 251, dtype: float64

# %%
#移動平均線を書く
#新しい列名を作って移動平均を格納する
ma_day = [10, 20, 50]
for ma in ma_day:
    column_name = 'MA {}'.format(ma)
    AAPL[column_name] = AAPL['Close'].rolling(ma).mean()

# %%
AAPL.head(15)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016
# %%
tech_rets = closing_df.pct_change()

# %%
tech_rets.head()
# Out:
#                 AAPL      AMZN      GOOG      MSFT
# Date
# 2017-12-01       NaN       NaN       NaN       NaN
# 2017-11-30  0.004677  0.012389  0.011127 -0.001068
# 2017-11-29 -0.013791 -0.013155  0.000245 -0.009861
# 2017-11-28  0.021183  0.027840  0.025204  0.018479
# 2017-11-27  0.005894  0.001868  0.006492 -0.011899

# %%
sns.jointplot('GOOG', 'GOOG', tech_rets, kind='scatter', color='seagreen')

# %%
sns.jointplot('GOOG', 'MSFT', tech_rets, kind='scatter', color='seagreen')

# %%
sns.pairplot(tech_rets.dropna())

# %%
returns_fig = sns.PairGrid(tech_rets.dropna())
returns_fig.map_upper(plt.scatter, color='purple')
returns_fig.map_lower(sns.kdeplot, cmap='cool_d')
returns_fig.map_diag(plt.hist, bins=30)

# %%
returns_fig = sns.PairGrid(closing_df)
returns_fig.map_upper(plt.scatter, color='purple')
returns_fig.map_lower(sns.kdeplot, cmap='cool_d')
returns_fig.map_diag(plt.hist, bins=30)

# %%
sns.heatmap(tech_rets.corr(), annot=True)

# %% [markdown]
# ### リスク解析
#  - リスクとリターンの関係を図示する

# %%
rets = tech_rets.dropna()

# %%
rets.head()
# Out:
#                 AAPL      AMZN      GOOG      MSFT
# Date
# 2017-11-30  0.004677  0.012389  0.011127 -0.001068
# 2017-11-29 -0.013791 -0.013155  0.000245 -0.009861
# 2017-11-28  0.021183  0.027840  0.025204  0.018479
# 2017-11-27  0.005894  0.001868  0.006492 -0.011899
# 2017-11-24  0.005055 -0.008220 -0.012901 -0.007273

# %%
#前日比を平均（収益）と標準偏差（リスク）でプロット
#numpyから直径1の円の面積*20
plt.scatter(rets.mean(), rets.std(), alpha=0.5, s=np.pi*20)

# %%
plt.scatter(rets.mean(), rets.std(), alpha=0.5, s=np.pi*20)
plt.ylim([0.005, 0.02])
plt.xlim([-0.005, 0.005])

plt.xlabel('Expectet returns')
plt.ylabel('Risc')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x,y), xytext=(-20,0),
                textcoords = 'offset points', ha = 'right', va = 'bottom',
                arrowprops = dict(arrowstyle='-', connectionstyle='arc3'))

# %% [markdown]
# ### value at risk

# %%
sns.distplot(AAPL['Daily Return'].dropna(), bins=100, color='purple')

# %%
#パーセンタイル
rets['AAPL'].quantile(0.05)
# Out:
# -0.017384648111063754

# %%
#一定期間での損失見積もりを95%信頼区間で表現
#ここでは1年後を予測する
days = 365
dt = 1/days
mu = rets.mean()['GOOG']
sigma = rets.std()['GOOG']

# %%
#ブラウン運動の数式をつくる
def stock_monte_carlo(start_price, days, mu, sigma):
    price = np.zeros(days) #arrayをつくる
    price[0] = start_price
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    for x in range(1, days):
        shock[x] = np.random.normal(loc=mu*dt, scale=sigma * np.sqrt(dt))
        drift[x] = mu * dt
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
    return price

# %%
GOOG.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-12-05  757.710022  763.900024  752.900024  762.520020  762.520020
# 2016-12-06  764.729980  768.830017  757.340027  759.109985  759.109985
# 2016-12-07  761.000000  771.359985  755.799988  771.190002  771.190002
# 2016-12-08  772.479980  778.179993  767.229980  776.419983  776.419983
# 2016-12-09  780.000000  789.429993  779.020996  789.289978  789.289978
#
#              Volume
# Date
# 2016-12-05  1394200
# 2016-12-06  1690700
# 2016-12-07  1761000
# 2016-12-08  1488100
# 2016-12-09  1821900

# %%
start_price = GOOG.iloc[0,4]

for run in range(5):
    plt.plot(stock_monte_carlo(start_price, days, mu, sigma))

plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Analysis')

# %%
#1万回シミュレーションする
runs = 10000
simulations = np.zeros(runs)
np.set_printoptions(threshold=5)
for run in range(runs):
    simulations[run] = stock_monte_carlo(start_price, days, mu, sigma)[days-1]

# %%
plt.hist(simulations, bins=200)
# Out:
# (array([ 1.,  0.,  0., ...,  0.,  0.,  1.]),
#  array([ 726.42309039,  726.74401219,  727.06493399, ...,  789.96560699,
#          790.28652879,  790.6074506 ]),
#  <a list of 200 Patch objects>)

# %%
#1パーセンタイルを見積もってみる
q = np.percentile(simulations, 1)
plt.hist(simulations, bins=200)

plt.figtext(0.6, 0.8, s='Start price: {:0.2f}'.format(start_price))
plt.figtext(0.6, 0.7, 'mean final price: {:0.2f}'.format(simulations.mean()))
plt.figtext(0.6, 0.6, 'VaR(0.99): {:0.2f}'.format(start_price-q))
plt.figtext(0.15, 0.6, 'q(0.99): {:0.2f}'.format(q))

plt.axvline(x = q, linewidth=4, color='r')
